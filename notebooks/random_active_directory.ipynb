# %% [markdown]
#  Copyright (c) Microsoft Corporation. All rights reserved. Licensed under the MIT License.
#
#
#
#  # Randomly generated CyberBattle network environment for Active Directory

# %%
import cyberbattle.samples.active_directory.generate_ad as ad
import cyberbattle.simulation.commandcontrol as commandcontrol
import logging, sys, random

random.seed(1)
logging.basicConfig(stream=sys.stdout, level=logging.INFO, format="%(levelname)s: %(message)s")
# %matplotlib inline

# %%
env = ad.new_random_environment(42)
env.plot_environment_graph()

# %%
c2 = commandcontrol.CommandControl(env)
dbg = commandcontrol.EnvironmentDebugging(c2)

# 1 - Start from client
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
#               status     properties  \
# id
# workstation_0  owned  [breach_node]
#
#                                                    local_attacks  \
# id
# workstation_0  [EnumerateFileShares, FindDomainControllers, P...
#
#               remote_attacks
# id
# workstation_0             []

# %%
outcome = c2.run_attack("workstation_0", "FindDomainControllers")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: domain_controller_1
# INFO: GOT REWARD: Found domain controllers
#                          status     properties  \
# id
# workstation_0             owned  [breach_node]
# domain_controller_1  discovered            NaN
#
#                                                          local_attacks  \
# id
# workstation_0        [EnumerateFileShares, FindDomainControllers, P...
# domain_controller_1                                               None
#
#                     remote_attacks
# id
# workstation_0                   []
# domain_controller_1             []

# %%
outcome = c2.run_attack("workstation_0", "EnumerateFileShares")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: share_0
# INFO: GOT REWARD: Found shares
#                          status     properties  \
# id
# workstation_0             owned  [breach_node]
# domain_controller_1  discovered            NaN
# share_0              discovered            NaN
#
#                                                          local_attacks  \
# id
# workstation_0        [EnumerateFileShares, FindDomainControllers, P...
# domain_controller_1                                               None
# share_0                                                           None
#
#                     remote_attacks
# id
# workstation_0                   []
# domain_controller_1             []
# share_0                         []

# %%
outcome = c2.run_attack("workstation_0", "AuthorizationSpoofAndCrack")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: share_0
# INFO: discovered credential: CachedCredential(node='share_0', port='SMB', credential='user_8')
# INFO: discovered node: share_0
# INFO: discovered credential: CachedCredential(node='share_0', port='SMB', credential='user_14')
# INFO: discovered node: share_0
# INFO: discovered credential: CachedCredential(node='share_0', port='SMB', credential='user_47')
# INFO: discovered node: workstation_3
# INFO: discovered credential: CachedCredential(node='workstation_3', port='SHELL', credential='user_8')
# INFO: discovered node: workstation_4
# INFO: discovered credential: CachedCredential(node='workstation_4', port='SHELL', credential='user_14')
# INFO: discovered node: workstation_2
# INFO: discovered credential: CachedCredential(node='workstation_2', port='SHELL', credential='user_47')
# INFO: GOT REWARD:
#                          status     properties  \
# id
# workstation_0             owned  [breach_node]
# domain_controller_1  discovered            NaN
# share_0              discovered            NaN
# workstation_3        discovered            NaN
# workstation_4        discovered            NaN
# workstation_2        discovered            NaN
#
#                                                          local_attacks  \
# id
# workstation_0        [EnumerateFileShares, FindDomainControllers, P...
# domain_controller_1                                               None
# share_0                                                           None
# workstation_3                                                     None
# workstation_4                                                     None
# workstation_2                                                     None
#
#                     remote_attacks
# id
# workstation_0                   []
# domain_controller_1             []
# share_0                         []
# workstation_3                   []
# workstation_4                   []
# workstation_2                   []

# %%
c2.connect_and_infect("workstation_0", "workstation_4", "SHELL", "user_28")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 c2.connect_and_infect("workstation_0", "workstation_4", "SHELL", "user_28")
#       2 dbg.plot_discovered_network()
#       3 c2.print_all_attacks()
#
# File ~/work/VITCyberSim/cyberbattle/simulation/commandcontrol.py:139, in CommandControl.connect_and_infect(self, source_node_id, target_node_id, port_name, credentials)
#     130 def connect_and_infect(
#     131     self,
#     132     source_node_id: model.NodeID,
#    (...)
#     135     credentials: model.CredentialID,
#     136 ) -> bool:
#     137     """Install the agent on a remote machine using the
#     138     provided credentials"""
# --> 139     result = self._actuator.connect_to_remote_machine(source_node_id, target_node_id, port_name, credentials)
#     140     self.__accumulate_reward(result.reward)
#     141     return result.outcome is not None
#
# File ~/work/VITCyberSim/cyberbattle/simulation/actions.py:563, in AgentActions.connect_to_remote_machine(self, source_node_id, target_node_id, port_name, credential)
#     561 if credential not in self._gathered_credentials:
#     562     if self._throws_on_invalid_actions:
# --> 563         raise ValueError(f"Agent has not discovered credential '{credential}'")
#     564     else:
#     565         return ActionResult(reward=Penalty.INVALID_ACTION, outcome=None)
#
# ValueError: Agent has not discovered credential 'user_28'

# %%
c2.run_attack("workstation_4", "ScanForCreds")
dbg.plot_discovered_network()
c2.print_all_attacks()

# %%
c2.connect_and_infect("workstation_0", "domain_controller_1", "AD", "dc_1")
dbg.plot_discovered_network()
c2.print_all_attacks()

# %%
c2.run_attack("domain_controller_1", "DumpNTDS")
dbg.plot_discovered_network()
c2.print_all_attacks()
