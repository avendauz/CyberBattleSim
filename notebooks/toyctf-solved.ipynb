# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved. Licensed under the MIT License.
#
# # Capture The Flag Toy Example - Solved manually

# %% [markdown]
# This notebook demonstrates how to model a toy `Capture The Flag` security game as a CyberBattle environment.

# %%
import sys, logging
import cyberbattle.simulation.model as model
import cyberbattle.simulation.commandcontrol as commandcontrol
import cyberbattle.samples.toyctf.toy_ctf as ctf

logging.basicConfig(stream=sys.stdout, level=logging.INFO, format="%(levelname)s: %(message)s")

import plotly.offline as plo

plo.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
network = model.create_network(ctf.nodes)
env = model.Environment(network=network, vulnerability_library=dict([]), identifiers=ctf.ENV_IDENTIFIERS)
env.plot_environment_graph()

# %% [markdown]
# ### Solution to the CTF
#
# This is the list of actions taken to capture 7 of the 8 flags from the CTF game.
#
# | Source      | Action | Result |
# |------------ | ------ | ------ |
# | WEBSITE     | page content has a link to github       | Discover Github project |
# | GITHUB      | navigate github history                 | **FLAG** Some secure access token (SAS) leaked in a reverted git commit (`CredScan`) |
# | AZURESTORAGE| access blob using SAS token             | |
# | WEBSITE     | view source HTML                        | Find URL to hidden .txt file on the website, extract directory path from it |
# |             | navigate to parent URL and find 3 files | **FLAG** Discover browseable web directory |
# |             | - readme.txt file                       | Discover secret data (the flag) |
# |             | - getting-started.txt                   | Discover MYSQL credentials |
# |             | - deprecation-checklist.txt             | Discover URL to external sharepoint website |
# | SHAREPOINT  | Navigate to sharepoint site             | **FLAG** Finding AD Service Principal Credentials on Sharepoint |
# | CLIENT-AZURE| `az resource` with creds from sharepoint| Obtain secrets hidden in azure managed resources |
# |             |                                         | Get AzureVM info, including public IP address |
# | CLIENT      | `ssh IP`                                | Failed attempt: internet incoming traffic blocked on the VM by NSG |
# | CLIENT      | SSH into WEBSITE with  mysql creds      | **FLAG** Shared credentials with database user|
# |             |                                         |**FLAG** Login using insecure SSH user/password|
# | WEBSITE/SSH | `history`                               |**FLAG**  Stealing credentials for the monitoring user|
# |             | `sudo -u monitor`                        | Failed! monitor not sudoable. message about being reported!
# | CLIENT      | SSH into WEBSITE with 'monitor creds     | Failed! password authentication disabled! looking for private key|
# | CLIENT      | SSH into WEBSITE as 'web'               | |
# |             | `su -u monitor` using password           |**FLAG**  User escalation by stealing credentials from bash history|
# |             | `cat ~/azurecreds.txt`                  | Get user credentials to Azure
# | CLIENT      | `az resource` with monitor's creds       | Steal more secrets

# %%
c2 = commandcontrol.CommandControl(env)
dbg = commandcontrol.EnvironmentDebugging(c2)

# 1 - Start from client
dbg.plot_discovered_network()

for node_id, node_data in env.nodes():
    print(node_id)
    print(node_data)
# Out:
# <div>                            <div id="98acbcca-e88e-45cc-bd8c-28296ef97272" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98acbcca-e88e-45cc-bd8c-28296ef97272")) {                    Plotly.newPlot(                        "98acbcca-e88e-45cc-bd8c-28296ef97272",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client"],"textposition":"bottom center","x":[0.0],"y":[0.0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":[],"textposition":"bottom center","x":[],"y":[],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterp ...
# Website
# NodeInfo(services=[ListeningService(name='HTTPS', allowedCredentials=[], running=True), ListeningService(name='SSH', allowedCredentials=['ReusedMySqlCred-web'], running=True)], vulnerabilities={'ScanPageContent': VulnerabilityInfo(description='LeakedGitHubProjectUrl: Website page content shows a link to GitHub repo', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedNodesId object at 0x7f6e2a2f07c0>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='WEBSITE page content has a link to github -> Github project discovered!'), 'ScanPageSource': VulnerabilityInfo(description='Website page source contains refrence to browseable relative web directory', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedNodesId object at 0x7f6e2a2f0820>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Viewing the web page source reveals a URL to a .txt file and directory on the website'), 'CredScanBashHistory': VulnerabilityInfo(description='bash history leaking creds - FLAG Stealing credentials for the monitoring user', type=<VulnerabilityType.LOCAL: 1>, outcome=<cyberbattle.simulation.model.LeakedCredentials object at 0x7f6e2a2f0880>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='FLAG: SSH history revealed credentials for the monitoring user (monitor)')}, value=100, properties=['MySql', 'Ubuntu', 'nginx/1.10.3'], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='su', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='sudo', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='FLAG: Login using insecure SSH user/password', sla_weight=1.0)
# Website.Directory
# NodeInfo(services=[ListeningService(name='HTTPS', allowedCredentials=[], running=True)], vulnerabilities={'NavigateWebDirectoryFurther': VulnerabilityInfo(description="Discover MYSQL credentials MySql for user 'web' in (getting-started.txt)", type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedCredentials object at 0x7f6e2a2f0970>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Discover browseable web directory: Navigating to parent URL revealed file `readme.txt`with secret data (aflag); and `getting-started.txt` with MYSQL credentials'), 'NavigateWebDirectory': VulnerabilityInfo(description='Discover URL to external sharepoint website (in deprecation-checklist.txt)', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedNodesId object at 0x7f6e2a2f09d0>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Navigating to parent URL revealed file `deprecation-checklist.txt` containinga URL to an external sharepoint website')}, value=50, properties=['Ubuntu', 'nginx/1.10.3', 'CTFFLAG:Readme.txt-Discover secret data'], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='', sla_weight=1.0)
# Website[user=monitor]
# NodeInfo(services=[ListeningService(name='SSH', allowedCredentials=[], running=True), ListeningService(name='SSH-key', allowedCredentials=['unkownkey'], running=True), ListeningService(name='su', allowedCredentials=['monitorBashCreds'], running=True)], vulnerabilities={'CredScan-HomeDirectory': VulnerabilityInfo(description='azurecredential.txt file in home directory', type=<VulnerabilityType.LOCAL: 1>, outcome=<cyberbattle.simulation.model.LeakedCredentials object at 0x7f6e2a2f1060>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='SSH: cat ~/azurecreds.txt (running as monitor) revealed Azure user credential!')}, value=100, properties=['MySql', 'Ubuntu', 'nginx/1.10.3'], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='SSH', permission=<RulePermission.BLOCK: 1>, reason='password authentication disabled! SSH needs private key to authenticate.'), FirewallRule(port='sudo', permission=<RulePermission.BLOCK: 1>, reason="`sudo -u monitor` failed. User 'monitor' not sudoable.This warning will be reported!"), FirewallRule(port='su', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='FLAG User escalation by stealing credentials from bash history', sla_weight=1.0)
# GitHubProject
# NodeInfo(services=[ListeningService(name='GIT', allowedCredentials=[], running=True)], vulnerabilities={'CredScanGitHistory': VulnerabilityInfo(description='Some secure access token (SAS) leaked in a reverted git commit', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedCredentials object at 0x7f6e2a2f12d0>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2a2f1150>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='CredScan success: Some secure access token (SAS) was leaked in a reverted git commit')}, value=10, properties=['GitHub', 'SasUrlInCommit'], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='', sla_weight=1.0)
# AzureStorage
# NodeInfo(services=[ListeningService(name='HTTPS', allowedCredentials=['SASTOKEN1'], running=True)], vulnerabilities={'AccessDataWithSASToken': VulnerabilityInfo(description='Stealing secrets using a publicly shared SAS token', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.CustomerData object at 0x7f6e2a2f1720>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Stole data using a publicly shared SAS token')}, value=50, properties=['CTFFLAG:LeakedCustomerData'], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='', sla_weight=1.0)
# Sharepoint
# NodeInfo(services=[ListeningService(name='HTTPS', allowedCredentials=[], running=True)], vulnerabilities={'ScanSharepointParentDirectory': VulnerabilityInfo(description='Navigate to SharePoint site, browse parent directory', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedCredentials object at 0x7f6e2a2f1cc0>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Navigating to the Sharepoint site revealed  AD Service Principal Credentials')}, value=100, properties=['SharepointLeakingPassword'], firewall=FirewallConfiguration(outgoing=[], incoming=[FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='', sla_weight=1.0)
# AzureResourceManager
# NodeInfo(services=[ListeningService(name='HTTPS', allowedCredentials=['ADPrincipalCreds', 'azuread_user_credentials'], running=True)], vulnerabilities={'ListAzureResources': VulnerabilityInfo(description='AzureVM info, including public IP address', type=<VulnerabilityType.REMOTE: 2>, outcome=<cyberbattle.simulation.model.LeakedNodesId object at 0x7f6e2a2f1db0>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Obtained Azure VM and public IP information')}, value=50, properties=['CTFFLAG:LeakedCustomerData2'], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='FLAG: Shared credentials with database user - Obtained secrets hidden in Azure Managed Resources', sla_weight=1.0)
# AzureResourceManager[user=monitor]
# NodeInfo(services=[ListeningService(name='HTTPS', allowedCredentials=['azuread_user_credentials'], running=True)], vulnerabilities={}, value=50, properties=[], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='More secrets stolen when logged as interactive `monitor` user in Azure with `az`', sla_weight=1.0)
# AzureVM
# NodeInfo(services=[ListeningService(name='PING', allowedCredentials=[], running=True), ListeningService(name='SSH', allowedCredentials=[], running=True)], vulnerabilities={}, value=100, properties=['CTFFLAG:VMPRIVATEINFO'], firewall=FirewallConfiguration(outgoing=[], incoming=[FirewallRule(port='SSH', permission=<RulePermission.BLOCK: 1>, reason='internet incoming traffic blocked on the VM by NSG firewall')]), agent_installed=False, privilege_level=<PrivilegeLevel.NoAccess: 0>, reimagable=True, last_reimaging=None, owned_string='', sla_weight=1.0)
# client
# NodeInfo(services=[], vulnerabilities={'SearchEdgeHistory': VulnerabilityInfo(description='Search web history for list of accessed websites', type=<VulnerabilityType.LOCAL: 1>, outcome=<cyberbattle.simulation.model.LeakedNodesId object at 0x7f6e2a2f2740>, precondition=<cyberbattle.simulation.model.Precondition object at 0x7f6e2c0b99f0>, rates=Rates(probingDetectionRate=0.0, exploitDetectionRate=0.0, successRate=1.0), URL='', cost=1.0, reward_string='Web browser history revealed website URL of interest')}, value=0, properties=[], firewall=FirewallConfiguration(outgoing=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')], incoming=[FirewallRule(port='RDP', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='SSH', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTPS', permission=<RulePermission.ALLOW: 0>, reason=''), FirewallRule(port='HTTP', permission=<RulePermission.ALLOW: 0>, reason='')]), agent_installed=True, privilege_level=<PrivilegeLevel.LocalUser: 1>, reimagable=False, last_reimaging=None, owned_string='', sla_weight=1.0)

# %%
c2.print_all_attacks()
print(c2.known_vulnerabilities())
env.get_node("client").vulnerabilities
c2.credentials_gathered_so_far
# Out:
#        status properties        local_attacks remote_attacks
# id
# client  owned         []  [SearchEdgeHistory]             []
# {}
# set()

# %%
outcome = c2.run_attack("client", "SearchEdgeHistory")
print(c2._actuator.get_discovered_properties("website"))
dbg.plot_discovered_network()
# Out:
# INFO: discovered node: Website
# INFO: GOT REWARD: Web browser history revealed website URL of interest
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 outcome = c2.run_attack("client", "SearchEdgeHistory")
# ----> 2 print(c2._actuator.get_discovered_properties("website"))
#       3 dbg.plot_discovered_network()
#
# File ~/work/VITCyberSim/cyberbattle/simulation/actions.py:227, in AgentActions.get_discovered_properties(self, node_id)
#     226 def get_discovered_properties(self, node_id: model.NodeID) -> Set[int]:
# --> 227     return self._discovered_nodes[node_id].discovered_properties
#
# KeyError: 'website'

# %%
c2.print_all_attacks()
# Out:
#              status properties        local_attacks  \
# id
# client        owned         []  [SearchEdgeHistory]
# Website  discovered        NaN                 None
#
#                             remote_attacks
# id
# client                                  []
# Website  [ScanPageContent, ScanPageSource]

# %%
# 2
github = c2.run_remote_attack("client", "Website", "ScanPageContent")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: GitHubProject
# INFO: GOT REWARD: WEBSITE page content has a link to github -> Github project discovered!
# <div>                            <div id="6760b9a3-56a3-43a6-975a-d2d0a77cce06" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6760b9a3-56a3-43a6-975a-d2d0a77cce06")) {                    Plotly.newPlot(                        "6760b9a3-56a3-43a6-975a-d2d0a77cce06",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client"],"textposition":"bottom center","x":[0.0],"y":[0.0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject"],"textposition":"bottom center","x":[-0.5,0.5],"y":[-4.371138828673793e-08,8.742277657347586e-08],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"ty ...
#                    status properties        local_attacks  \
# id
# client              owned         []  [SearchEdgeHistory]
# Website        discovered        NaN                 None
# GitHubProject  discovered        NaN                 None
#
#                                   remote_attacks
# id
# client                                        []
# Website        [ScanPageSource, ScanPageContent]
# GitHubProject               [CredScanGitHistory]

# %%
# 3
leakedSasUrl = c2.run_remote_attack("client", "GitHubProject", "CredScanGitHistory")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: AzureStorage
# INFO: discovered credential: CachedCredential(node='AzureStorage', port='HTTPS', credential='SASTOKEN1')
# INFO: GOT REWARD: CredScan success: Some secure access token (SAS) was leaked in a reverted git commit
# <div>                            <div id="d0d574d6-e647-43a8-9b23-bc2c7a8d0efe" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0d574d6-e647-43a8-9b23-bc2c7a8d0efe")) {                    Plotly.newPlot(                        "d0d574d6-e647-43a8-9b23-bc2c7a8d0efe",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client"],"textposition":"bottom center","x":[0.0],"y":[0.0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","AzureStorage"],"textposition":"bottom center","x":[-0.5,0.24999995529651642,0.24999980628490448],"y":[-4.371138828673793e-08,-0.4330127239227295,0.43301281332969666],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"ov ...
#                    status properties        local_attacks  \
# id
# client              owned         []  [SearchEdgeHistory]
# Website        discovered        NaN                 None
# GitHubProject  discovered        NaN                 None
# AzureStorage   discovered        NaN                 None
#
#                                   remote_attacks
# id
# client                                        []
# Website        [ScanPageSource, ScanPageContent]
# GitHubProject               [CredScanGitHistory]
# AzureStorage            [AccessDataWithSASToken]

# %%
# 4
blobwithflag = c2.connect_and_infect("client", "AzureStorage", "HTTPS", "SASTOKEN1")
dbg.plot_discovered_network()
blobwithflag
c2.print_all_attacks()
print(c2._actuator.get_discovered_properties("GithubProject"))
print(env.identifiers[0])
# Out:
# <div>                            <div id="b9a2b571-41b7-4081-bb73-05fe9a2c74a9" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9a2b571-41b7-4081-bb73-05fe9a2c74a9")) {                    Plotly.newPlot(                        "b9a2b571-41b7-4081-bb73-05fe9a2c74a9",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage"],"textposition":"bottom center","x":[0.0,0.24999980628490448],"y":[0.0,0.43301281332969666],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject"],"textposition":"bottom center","x":[-0.5,0.24999995529651642],"y":[-4.371138828673793e-08,-0.4330127239227295],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"ov ...
#                    status                    properties        local_attacks  \
# id
# client              owned                            []  [SearchEdgeHistory]
# AzureStorage        owned  [CTFFLAG:LeakedCustomerData]                   []
# Website        discovered                           NaN                 None
# GitHubProject  discovered                           NaN                 None
#
#                                   remote_attacks
# id
# client                                        []
# AzureStorage            [AccessDataWithSASToken]
# Website        [ScanPageSource, ScanPageContent]
# GitHubProject               [CredScanGitHistory]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 6
#       4 blobwithflag
#       5 c2.print_all_attacks()
# ----> 6 print(c2._actuator.get_discovered_properties("GithubProject"))
#       7 print(env.identifiers[0])
#
# File ~/work/VITCyberSim/cyberbattle/simulation/actions.py:227, in AgentActions.get_discovered_properties(self, node_id)
#     226 def get_discovered_properties(self, node_id: model.NodeID) -> Set[int]:
# --> 227     return self._discovered_nodes[node_id].discovered_properties
#
# KeyError: 'GithubProject'

# %%
# 5
browsableDirectory = c2.run_remote_attack("client", "Website", "ScanPageSource")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: Website.Directory
# INFO: GOT REWARD: Viewing the web page source reveals a URL to a .txt file and directory on the website
# <div>                            <div id="28060007-6154-4a29-8345-6a3751a217f9" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28060007-6154-4a29-8345-6a3751a217f9")) {                    Plotly.newPlot(                        "28060007-6154-4a29-8345-6a3751a217f9",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage"],"textposition":"bottom center","x":[0.0,0.5],"y":[0.0,8.742277657347586e-08],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","Website.Directory"],"textposition":"bottom center","x":[-0.5,5.962440319251527e-09,-1.6888311904494913e-07],"y":[-4.371138828673793e-08,-0.5,0.5],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpat ...
#                        status                    properties  \
# id
# client                  owned                            []
# AzureStorage            owned  [CTFFLAG:LeakedCustomerData]
# Website            discovered                           NaN
# GitHubProject      discovered                           NaN
# Website.Directory  discovered                           NaN
#
#                          local_attacks  \
# id
# client             [SearchEdgeHistory]
# AzureStorage                        []
# Website                           None
# GitHubProject                     None
# Website.Directory                 None
#
#                                                       remote_attacks
# id
# client                                                            []
# AzureStorage                                [AccessDataWithSASToken]
# Website                            [ScanPageContent, ScanPageSource]
# GitHubProject                                   [CredScanGitHistory]
# Website.Directory  [NavigateWebDirectory, NavigateWebDirectoryFur...

# %%
# 6
outcome_mysqlleak = c2.run_remote_attack("client", "Website.Directory", "NavigateWebDirectoryFurther")
sharepoint_url = c2.run_remote_attack("client", "Website.Directory", "NavigateWebDirectory")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: Website
# INFO: discovered credential: CachedCredential(node='Website', port='MySQL', credential='ReusedMySqlCred-web')
# INFO: GOT REWARD: Discover browseable web directory: Navigating to parent URL revealed file `readme.txt`with secret data (aflag); and `getting-started.txt` with MYSQL credentials
# INFO: discovered node: Sharepoint
# INFO: GOT REWARD: Navigating to parent URL revealed file `deprecation-checklist.txt` containinga URL to an external sharepoint website
# <div>                            <div id="727e3f7f-0e6a-4156-b5c6-b22a6a8eec6c" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("727e3f7f-0e6a-4156-b5c6-b22a6a8eec6c")) {                    Plotly.newPlot(                        "727e3f7f-0e6a-4156-b5c6-b22a6a8eec6c",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage"],"textposition":"bottom center","x":[0.0,0.4045086205005646],"y":[0.0,-0.2938924729824066],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","Website.Directory","Sharepoint"],"textposition":"bottom center","x":[-0.5,-0.1545085608959198,0.404508501291275,-0.15450870990753174],"y":[-4.371138828673793e-08,-0.4755282402038574,0.29389262199401855,0.47552818059921265],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}], ...
#                        status                    properties  \
# id
# client                  owned                            []
# AzureStorage            owned  [CTFFLAG:LeakedCustomerData]
# Website            discovered                           NaN
# GitHubProject      discovered                           NaN
# Website.Directory  discovered                           NaN
# Sharepoint         discovered                           NaN
#
#                          local_attacks  \
# id
# client             [SearchEdgeHistory]
# AzureStorage                        []
# Website                           None
# GitHubProject                     None
# Website.Directory                 None
# Sharepoint                        None
#
#                                                       remote_attacks
# id
# client                                                            []
# AzureStorage                                [AccessDataWithSASToken]
# Website                            [ScanPageContent, ScanPageSource]
# GitHubProject                                   [CredScanGitHistory]
# Website.Directory  [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                           [ScanSharepointParentDirectory]

# %%
# 7
outcome_azure_ad = c2.run_remote_attack("client", "Sharepoint", "ScanSharepointParentDirectory")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: AzureResourceManager
# INFO: discovered credential: CachedCredential(node='AzureResourceManager', port='HTTPS', credential='ADPrincipalCreds')
# INFO: GOT REWARD: Navigating to the Sharepoint site revealed  AD Service Principal Credentials
# <div>                            <div id="ac2b7ace-dd88-46ff-83ce-7396a569834e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac2b7ace-dd88-46ff-83ce-7396a569834e")) {                    Plotly.newPlot(                        "ac2b7ace-dd88-46ff-83ce-7396a569834e",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage"],"textposition":"bottom center","x":[0.0,0.24999995529651642],"y":[0.0,-0.4330127239227295],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","Website.Directory","Sharepoint","AzureResourceManager"],"textposition":"bottom center","x":[-0.5,-0.24999995529651642,0.5,0.24999980628490448,-0.25000011920928955],"y":[-4.371138828673793e-08,-0.4330127239227295,8.742277657347586e-08,0.43301281332969666,0.43301263451576233],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a ...
#                           status                    properties  \
# id
# client                     owned                            []
# AzureStorage               owned  [CTFFLAG:LeakedCustomerData]
# Website               discovered                           NaN
# GitHubProject         discovered                           NaN
# Website.Directory     discovered                           NaN
# Sharepoint            discovered                           NaN
# AzureResourceManager  discovered                           NaN
#
#                             local_attacks  \
# id
# client                [SearchEdgeHistory]
# AzureStorage                           []
# Website                              None
# GitHubProject                        None
# Website.Directory                    None
# Sharepoint                           None
# AzureResourceManager                 None
#
#                                                          remote_attacks
# id
# client                                                               []
# AzureStorage                                   [AccessDataWithSASToken]
# Website                               [ScanPageContent, ScanPageSource]
# GitHubProject                                      [CredScanGitHistory]
# Website.Directory     [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                              [ScanSharepointParentDirectory]
# AzureResourceManager                               [ListAzureResources]

# %%
# 8
azureVmInfo = c2.connect_and_infect("client", "AzureResourceManager", "HTTPS", "ADPrincipalCreds")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: Infected node 'AzureResourceManager' from 'client' via HTTPS with credential 'ADPrincipalCreds'
# INFO: Owned message: FLAG: Shared credentials with database user - Obtained secrets hidden in Azure Managed Resources
# <div>                            <div id="a76342f5-779a-435b-a671-dc2db5bf5336" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a76342f5-779a-435b-a671-dc2db5bf5336")) {                    Plotly.newPlot(                        "a76342f5-779a-435b-a671-dc2db5bf5336",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,0.24999995529651642,-0.25000011920928955],"y":[0.0,-0.4330127239227295,0.43301263451576233],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","Website.Directory","Sharepoint"],"textposition":"bottom center","x":[-0.5,-0.24999995529651642,0.5,0.24999980628490448],"y":[-4.371138828673793e-08,-0.4330127239227295,8.742277657347586e-08,0.43301281332969666],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a ...
#                           status                     properties  \
# id
# client                     owned                             []
# AzureStorage               owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager       owned  [CTFFLAG:LeakedCustomerData2]
# Website               discovered                            NaN
# GitHubProject         discovered                            NaN
# Website.Directory     discovered                            NaN
# Sharepoint            discovered                            NaN
#
#                             local_attacks  \
# id
# client                [SearchEdgeHistory]
# AzureStorage                           []
# AzureResourceManager                   []
# Website                              None
# GitHubProject                        None
# Website.Directory                    None
# Sharepoint                           None
#
#                                                          remote_attacks
# id
# client                                                               []
# AzureStorage                                   [AccessDataWithSASToken]
# AzureResourceManager                               [ListAzureResources]
# Website                               [ScanPageContent, ScanPageSource]
# GitHubProject                                      [CredScanGitHistory]
# Website.Directory     [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                              [ScanSharepointParentDirectory]

# %%
c2.run_remote_attack("client", "AzureResourceManager", "ListAzureResources")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: AzureVM
# INFO: GOT REWARD: Obtained Azure VM and public IP information
# <div>                            <div id="9421497d-224d-446e-b3c5-14894785fb8e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9421497d-224d-446e-b3c5-14894785fb8e")) {                    Plotly.newPlot(                        "9421497d-224d-446e-b3c5-14894785fb8e",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,0.11126051843166351,0.11126034706830978],"y":[0.0,-0.48746395111083984,0.48746398091316223],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","Website.Directory","Sharepoint","AzureVM"],"textposition":"bottom center","x":[-0.5,-0.3117448091506958,0.45048442482948303,0.4504844546318054,-0.3117447793483734],"y":[-4.371138828673793e-08,-0.39091581106185913,-0.21694187819957733,0.21694181859493256,0.3909158408641815],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...
#                           status                     properties  \
# id
# client                     owned                             []
# AzureStorage               owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager       owned  [CTFFLAG:LeakedCustomerData2]
# Website               discovered                            NaN
# GitHubProject         discovered                            NaN
# Website.Directory     discovered                            NaN
# Sharepoint            discovered                            NaN
# AzureVM               discovered                            NaN
#
#                             local_attacks  \
# id
# client                [SearchEdgeHistory]
# AzureStorage                           []
# AzureResourceManager                   []
# Website                              None
# GitHubProject                        None
# Website.Directory                    None
# Sharepoint                           None
# AzureVM                              None
#
#                                                          remote_attacks
# id
# client                                                               []
# AzureStorage                                   [AccessDataWithSASToken]
# AzureResourceManager                               [ListAzureResources]
# Website                               [ScanPageContent, ScanPageSource]
# GitHubProject                                      [CredScanGitHistory]
# Website.Directory     [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                              [ScanSharepointParentDirectory]
# AzureVM                                                              []

# %%
# 9 - CLIENT: Attempt to SSH into AzureVM from IP retrieved from Azure Resource Manager
should_fail = c2.connect_and_infect("client", "AzureVM", "SSH", "ReusedMySqlCred-web")
print("Success=" + str(should_fail))
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: BLOCKED TRAFFIC: target node 'AzureVM' is blocking incoming traffic on port 'SSH'
# Success=False
# <div>                            <div id="4e7e3533-e6ac-485f-b11f-84780a8978a6" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e7e3533-e6ac-485f-b11f-84780a8978a6")) {                    Plotly.newPlot(                        "4e7e3533-e6ac-485f-b11f-84780a8978a6",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,0.11126051843166351,0.11126034706830978],"y":[0.0,-0.48746395111083984,0.48746398091316223],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["Website","GitHubProject","Website.Directory","Sharepoint","AzureVM"],"textposition":"bottom center","x":[-0.5,-0.3117448091506958,0.45048442482948303,0.4504844546318054,-0.3117447793483734],"y":[-4.371138828673793e-08,-0.39091581106185913,-0.21694187819957733,0.21694181859493256,0.3909158408641815],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...
#                           status                     properties  \
# id
# client                     owned                             []
# AzureStorage               owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager       owned  [CTFFLAG:LeakedCustomerData2]
# Website               discovered                            NaN
# GitHubProject         discovered                            NaN
# Website.Directory     discovered                            NaN
# Sharepoint            discovered                            NaN
# AzureVM               discovered                            NaN
#
#                             local_attacks  \
# id
# client                [SearchEdgeHistory]
# AzureStorage                           []
# AzureResourceManager                   []
# Website                              None
# GitHubProject                        None
# Website.Directory                    None
# Sharepoint                           None
# AzureVM                              None
#
#                                                          remote_attacks
# id
# client                                                               []
# AzureStorage                                   [AccessDataWithSASToken]
# AzureResourceManager                               [ListAzureResources]
# Website                               [ScanPageContent, ScanPageSource]
# GitHubProject                                      [CredScanGitHistory]
# Website.Directory     [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                              [ScanSharepointParentDirectory]
# AzureVM                                                              []

# %%
# 10
owned = c2.connect_and_infect("client", "Website", "SSH", "ReusedMySqlCred-web")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: Infected node 'Website' from 'client' via SSH with credential 'ReusedMySqlCred-web'
# INFO: Owned message: FLAG: Login using insecure SSH user/password
# <div>                            <div id="1f364864-53e8-445f-b949-94118e7b964e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f364864-53e8-445f-b949-94118e7b964e")) {                    Plotly.newPlot(                        "1f364864-53e8-445f-b949-94118e7b964e",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,-0.5,0.11126051843166351,0.11126034706830978],"y":[0.0,-4.371138828673793e-08,-0.48746395111083984,0.48746398091316223],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM"],"textposition":"bottom center","x":[-0.3117448091506958,0.45048442482948303,0.4504844546318054,-0.3117447793483734],"y":[-0.39091581106185913,-0.21694187819957733,0.21694181859493256,0.3909158408641815],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...
#                           status                     properties  \
# id
# client                     owned                             []
# Website                    owned  [MySql, Ubuntu, nginx/1.10.3]
# AzureStorage               owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager       owned  [CTFFLAG:LeakedCustomerData2]
# GitHubProject         discovered                            NaN
# Website.Directory     discovered                            NaN
# Sharepoint            discovered                            NaN
# AzureVM               discovered                            NaN
#
#                               local_attacks  \
# id
# client                  [SearchEdgeHistory]
# Website               [CredScanBashHistory]
# AzureStorage                             []
# AzureResourceManager                     []
# GitHubProject                          None
# Website.Directory                      None
# Sharepoint                             None
# AzureVM                                None
#
#                                                          remote_attacks
# id
# client                                                               []
# Website                               [ScanPageContent, ScanPageSource]
# AzureStorage                                   [AccessDataWithSASToken]
# AzureResourceManager                               [ListAzureResources]
# GitHubProject                                      [CredScanGitHistory]
# Website.Directory     [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                              [ScanSharepointParentDirectory]
# AzureVM                                                              []

# %%
# 11
outcome = c2.run_attack("Website", "CredScanBashHistory")
dbg.plot_discovered_network()
c2.print_all_attacks()
# Out:
# INFO: discovered node: Website[user=monitor]
# INFO: discovered credential: CachedCredential(node='Website[user=monitor]', port='SSH', credential='monitorBashCreds')
# INFO: GOT REWARD: FLAG: SSH history revealed credentials for the monitoring user (monitor)
# <div>                            <div id="7a93e90b-234f-4d2f-bd38-cc36577e7da5" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a93e90b-234f-4d2f-bd38-cc36577e7da5")) {                    Plotly.newPlot(                        "7a93e90b-234f-4d2f-bd38-cc36577e7da5",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,-0.5,5.962440319251527e-09,0.3535533845424652],"y":[0.0,-4.371138828673793e-08,-0.5,0.3535533845424652],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM","Website[user=monitor]"],"textposition":"bottom center","x":[-0.3535533547401428,0.35355350375175476,0.5,-1.6888311904494913e-07,-0.35355329513549805],"y":[-0.35355344414711,-0.35355326533317566,8.742277657347586e-08,0.5,0.35355350375175476],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...
#                            status                     properties  \
# id
# client                      owned                             []
# Website                     owned  [MySql, Ubuntu, nginx/1.10.3]
# AzureStorage                owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager        owned  [CTFFLAG:LeakedCustomerData2]
# GitHubProject          discovered                            NaN
# Website.Directory      discovered                            NaN
# Sharepoint             discovered                            NaN
# AzureVM                discovered                            NaN
# Website[user=monitor]  discovered                            NaN
#
#                                local_attacks  \
# id
# client                   [SearchEdgeHistory]
# Website                [CredScanBashHistory]
# AzureStorage                              []
# AzureResourceManager                      []
# GitHubProject                           None
# Website.Directory                       None
# Sharepoint                              None
# AzureVM                                 None
# Website[user=monitor]                   None
#
#                                                           remote_attacks
# id
# client                                                                []
# Website                                [ScanPageContent, ScanPageSource]
# AzureStorage                                    [AccessDataWithSASToken]
# AzureResourceManager                                [ListAzureResources]
# GitHubProject                                       [CredScanGitHistory]
# Website.Directory      [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                               [ScanSharepointParentDirectory]
# AzureVM                                                               []
# Website[user=monitor]                                                 []

# %%
c2.print_all_attacks()
# Out:
#                            status                     properties  \
# id
# client                      owned                             []
# Website                     owned  [MySql, Ubuntu, nginx/1.10.3]
# AzureStorage                owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager        owned  [CTFFLAG:LeakedCustomerData2]
# GitHubProject          discovered                            NaN
# Website.Directory      discovered                            NaN
# Sharepoint             discovered                            NaN
# AzureVM                discovered                            NaN
# Website[user=monitor]  discovered                            NaN
#
#                                local_attacks  \
# id
# client                   [SearchEdgeHistory]
# Website                [CredScanBashHistory]
# AzureStorage                              []
# AzureResourceManager                      []
# GitHubProject                           None
# Website.Directory                       None
# Sharepoint                              None
# AzureVM                                 None
# Website[user=monitor]                   None
#
#                                                           remote_attacks
# id
# client                                                                []
# Website                                [ScanPageContent, ScanPageSource]
# AzureStorage                                    [AccessDataWithSASToken]
# AzureResourceManager                                [ListAzureResources]
# GitHubProject                                       [CredScanGitHistory]
# Website.Directory      [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                               [ScanSharepointParentDirectory]
# AzureVM                                                               []
# Website[user=monitor]                                                 []

# %%
# 12
should_fail = c2.connect_and_infect("Website", "Website[user=monitor]", "sudo", "monitorBashCreds")
dbg.plot_discovered_network()
# Out:
# INFO: BLOCKED TRAFFIC: target node 'Website[user=monitor]' is blocking incoming traffic on port 'sudo'
# <div>                            <div id="dfbf6df9-86d6-4b09-8aa1-2426745bebeb" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfbf6df9-86d6-4b09-8aa1-2426745bebeb")) {                    Plotly.newPlot(                        "dfbf6df9-86d6-4b09-8aa1-2426745bebeb",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,-0.5,5.962440319251527e-09,0.3535533845424652],"y":[0.0,-4.371138828673793e-08,-0.5,0.3535533845424652],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM","Website[user=monitor]"],"textposition":"bottom center","x":[-0.3535533547401428,0.35355350375175476,0.5,-1.6888311904494913e-07,-0.35355329513549805],"y":[-0.35355344414711,-0.35355326533317566,8.742277657347586e-08,0.5,0.35355350375175476],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...

# %%
# 13
should_fail = c2.connect_and_infect("client", "Website[user=monitor]", "SSH", "monitorBashCreds")
dbg.plot_discovered_network()
should_fail
# Out:
# INFO: BLOCKED TRAFFIC: target node 'Website[user=monitor]' is blocking incoming traffic on port 'SSH'
# <div>                            <div id="98c2a64b-fd12-4b57-8cbf-b47f423ca0a4" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98c2a64b-fd12-4b57-8cbf-b47f423ca0a4")) {                    Plotly.newPlot(                        "98c2a64b-fd12-4b57-8cbf-b47f423ca0a4",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager"],"textposition":"bottom center","x":[0.0,-0.5,5.962440319251527e-09,0.3535533845424652],"y":[0.0,-4.371138828673793e-08,-0.5,0.3535533845424652],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM","Website[user=monitor]"],"textposition":"bottom center","x":[-0.3535533547401428,0.35355350375175476,0.5,-1.6888311904494913e-07,-0.35355329513549805],"y":[-0.35355344414711,-0.35355326533317566,8.742277657347586e-08,0.5,0.35355350375175476],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...
# False

# %%
# 14
flag = c2.connect_and_infect("Website", "Website[user=monitor]", "su", "monitorBashCreds")
dbg.plot_discovered_network()
# Out:
# INFO: Infected node 'Website[user=monitor]' from 'Website' via su with credential 'monitorBashCreds'
# INFO: Owned message: FLAG User escalation by stealing credentials from bash history
# <div>                            <div id="32dfd5e9-27cb-43d2-986c-0a388de23c0a" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32dfd5e9-27cb-43d2-986c-0a388de23c0a")) {                    Plotly.newPlot(                        "32dfd5e9-27cb-43d2-986c-0a388de23c0a",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager","Website[user=monitor]"],"textposition":"bottom center","x":[0.0,-0.5,5.962440319251527e-09,0.3535533845424652,-0.35355329513549805],"y":[0.0,-4.371138828673793e-08,-0.5,0.3535533845424652,0.35355350375175476],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM"],"textposition":"bottom center","x":[-0.3535533547401428,0.35355350375175476,0.5,-1.6888311904494913e-07],"y":[-0.35355344414711,-0.35355326533317566,8.742277657347586e-08,0.5],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...

# %%
# 15
outcome = c2.run_attack("Website[user=monitor]", "CredScan-HomeDirectory")
dbg.plot_discovered_network()
# Out:
# INFO: discovered node: AzureResourceManager[user=monitor]
# INFO: discovered credential: CachedCredential(node='AzureResourceManager[user=monitor]', port='HTTPS', credential='azuread_user_credentials')
# INFO: GOT REWARD: SSH: cat ~/azurecreds.txt (running as monitor) revealed Azure user credential!
# <div>                            <div id="ec56187c-5e34-4180-9275-12ca4fd274e6" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec56187c-5e34-4180-9275-12ca4fd274e6")) {                    Plotly.newPlot(                        "ec56187c-5e34-4180-9275-12ca4fd274e6",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager","Website[user=monitor]"],"textposition":"bottom center","x":[0.0,-0.5,-0.08682406693696976,0.46984627842903137,-0.08682423830032349],"y":[0.0,-4.371138828673793e-08,-0.49240389466285706,0.1710101217031479,0.4924038350582123],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM","AzureResourceManager[user=monitor]"],"textposition":"bottom center","x":[-0.38302215933799744,0.24999995529651642,0.46984627842903137,0.24999980628490448,-0.383022278547287],"y":[-0.3213938772678375,-0.4330127239227295,-0.17101018130779266,0.43301281332969666,0.321393758058548],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %%
# 16
secrets = c2.connect_and_infect("client", "AzureResourceManager[user=monitor]", "HTTPS", "azuread_user_credentials")
dbg.plot_discovered_network()
# Out:
# INFO: Infected node 'AzureResourceManager[user=monitor]' from 'client' via HTTPS with credential 'azuread_user_credentials'
# INFO: Owned message: More secrets stolen when logged as interactive `monitor` user in Azure with `az`
# <div>                            <div id="d965a0ec-16bd-43b0-95b8-9f882e915ebb" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d965a0ec-16bd-43b0-95b8-9f882e915ebb")) {                    Plotly.newPlot(                        "d965a0ec-16bd-43b0-95b8-9f882e915ebb",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager","Website[user=monitor]","AzureResourceManager[user=monitor]"],"textposition":"bottom center","x":[0.0,-0.5,-0.08682406693696976,0.46984627842903137,-0.08682423830032349,-0.383022278547287],"y":[0.0,-4.371138828673793e-08,-0.49240389466285706,0.1710101217031479,0.4924038350582123,0.321393758058548],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM"],"textposition":"bottom center","x":[-0.38302215933799744,0.24999995529651642,0.46984627842903137,0.24999980628490448],"y":[-0.3213938772678375,-0.4330127239227295,-0.17101018130779266,0.43301281332969666],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %%
c2.print_all_attacks()
# Out:
#                                         status                     properties  \
# id
# client                                   owned                             []
# Website                                  owned  [MySql, Ubuntu, nginx/1.10.3]
# AzureStorage                             owned   [CTFFLAG:LeakedCustomerData]
# AzureResourceManager                     owned  [CTFFLAG:LeakedCustomerData2]
# Website[user=monitor]                    owned  [MySql, Ubuntu, nginx/1.10.3]
# AzureResourceManager[user=monitor]       owned                             []
# GitHubProject                       discovered                            NaN
# Website.Directory                   discovered                            NaN
# Sharepoint                          discovered                            NaN
# AzureVM                             discovered                            NaN
#
#                                                local_attacks  \
# id
# client                                   [SearchEdgeHistory]
# Website                                [CredScanBashHistory]
# AzureStorage                                              []
# AzureResourceManager                                      []
# Website[user=monitor]               [CredScan-HomeDirectory]
# AzureResourceManager[user=monitor]                        []
# GitHubProject                                           None
# Website.Directory                                       None
# Sharepoint                                              None
# AzureVM                                                 None
#
#                                                                        remote_attacks
# id
# client                                                                             []
# Website                                             [ScanPageContent, ScanPageSource]
# AzureStorage                                                 [AccessDataWithSASToken]
# AzureResourceManager                                             [ListAzureResources]
# Website[user=monitor]                                                              []
# AzureResourceManager[user=monitor]                                                 []
# GitHubProject                                                    [CredScanGitHistory]
# Website.Directory                   [NavigateWebDirectory, NavigateWebDirectoryFur...
# Sharepoint                                            [ScanSharepointParentDirectory]
# AzureVM                                                                            []

# %%
secrets = c2.connect_and_infect("client", "AzureResourceManager[user=monitor]", "HTTPS", "azuread_user_credentials")
print(c2.known_vulnerabilities())

dbg.plot_discovered_network()
# Out:
# {}
# <div>                            <div id="24269c34-1ce5-4201-ba03-8f8cb7f9832f" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24269c34-1ce5-4201-ba03-8f8cb7f9832f")) {                    Plotly.newPlot(                        "24269c34-1ce5-4201-ba03-8f8cb7f9832f",                        [{"line":{"color":"gray"},"mode":"lines","name":"KNOWS","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"orange"},"mode":"lines","name":"REMOTE_EXPLOIT","x":[0],"y":[0],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"LATERAL_MOVE","x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#D32F2E","line":{"color":"rgb(255,0,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"owned","text":["client","Website","AzureStorage","AzureResourceManager","Website[user=monitor]","AzureResourceManager[user=monitor]"],"textposition":"bottom center","x":[0.0,-0.5,-0.08682406693696976,0.46984627842903137,-0.08682423830032349,-0.383022278547287],"y":[0.0,-4.371138828673793e-08,-0.49240389466285706,0.1710101217031479,0.4924038350582123,0.321393758058548],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#0e9d00","line":{"color":"rgb(0,255,0)","width":8},"size":5,"symbol":"circle-dot"},"mode":"markers+text","name":"discovered","text":["GitHubProject","Website.Directory","Sharepoint","AzureVM"],"textposition":"bottom center","x":[-0.38302215933799744,0.24999995529651642,0.46984627842903137,0.24999980628490448],"y":[-0.3213938772678375,-0.4330127239227295,-0.17101018130779266,0.43301281332969666],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %%
env.plot_environment_graph()
import networkx as nx
import json

import cyberbattle.VITAMIN.to_cgs as to_cgs
import cyberbattle.VITAMIN.countermeasures as cm

defender = (to_cgs.VulCGSBuilder(env, cm.ReimagingCountermeasure(env))
                .add_states()
                .add_weighted_edges()
                .generate_defender())

defender.export_to_vitamin("temp.txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       5 import cyberbattle.VITAMIN.to_cgs as to_cgs
#       6 import cyberbattle.VITAMIN.countermeasures as cm
# ----> 8 defender = (to_cgs.VulCGSBuilder(env, cm.ReimagingCountermeasure(env))
#       9                 .add_states()
#      10                 .add_weighted_edges()
#      11                 .generate_defender())
#      13 defender.export_to_vitamin("temp.txt")
#
# TypeError: VulCGSBuilder.__init__() takes 2 positional arguments but 3 were given

# %%
print(defender.graph.nodes())
